# %% [markdown]
# # BioModTool validation: iRC1080 GEM

# %% [markdown]
# - Cobra model: iRC1080 (Chlamydomonas reinhardtii) (Chang et al., 2011)
#
# - Biomass composition data : Autotrophic (Chang et al., 2011)

# %%
from cobra.flux_analysis.parsimonious import pfba as pfba_cobra

import BioModTool.load
import BioModTool.main_add_biomass_objective_function
import BioModTool.save

# %% [markdown]
# ### 1 - Load Genome Scale Metabolic Model

# %% [markdown]
# ##### 1.a) Model directory

# %% [markdown]
# GEM model must be given as a json or sbml/xml file.

# %%
path_to_model = "iRC1080.xml"

# %%
original_model = BioModTool.load.load_cobra_model(path_to_model)
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_h "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_m "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_x "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthfglu_DASH_L_c "10-Formyltetrahydrofolyl L-glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthfglu_DASH_L_m "10-Formyltetrahydrofolyl L-glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr16018111Z_c "1,2-Diacyl-sn-glycerol (1-hexadecanoyl,2-(11Z)-octadecenoyl, 16:0/18:1(11Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1601819Z_c "1,2-Diacyl-sn-glycerol (1-hexadecanoyl,2-(9Z)-octadecenoyl, 16:0/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1601819Z_h "1,2-Diacyl-sn-glycerol (1-hexadecanoyl,2-(9Z)-octadecenoyl, 16:0/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1801819Z_c "1,2-Diacyl-sn-glycerol (1-octadecanoyl,2-(9Z)-octadecenoyl, 18:0/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1801819Z_h "1,2-Diacyl-sn-glycerol (1-octadecanoyl,2-(9Z)-octadecenoyl, 18:0/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr18111Z18111Z_c "1,2-Diacyl-sn-glycerol (1,2-di-(11Z)-octadecenoyl, 18:1(11Z)/18:1(11Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr18111Z1819Z_c "1,2-Diacyl-sn-glycerol (1-(11Z)-octadecenoyl,2-(9Z)-octadecenoyl, 18:1(11Z)/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr18111Z1819Z_h "1,2-Diacyl-sn-glycerol (1-(11Z)-octadecenoyl,2-(9Z)-octadecenoyl, 18:1(11Z)/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1819Z18111Z_c "1,2-Diacyl-sn-glycerol (1-(9Z)-octadecenoyl,2-(11Z)-octadecenoyl, 18:1(9Z)/18:1(11Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1819Z18111Z_h "1,2-Diacyl-sn-glycerol (1-(9Z)-octadecenoyl,2-(11Z)-octadecenoyl, 18:1(9Z)/18:1(11Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1819Z1819Z_c "1,2-Diacyl-sn-glycerol (1,2-di-(9Z)-octadecenoyl, 18:1(9Z)/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr1819Z1819Z_h "1,2-Diacyl-sn-glycerol (1,2-di-(9Z)-octadecenoyl, 18:1(9Z)/18:1(9Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dmpo_c "1,2-Dihydroxy-5-(methylthio)pent-1-en-3-one">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13dpg_c "3-Phospho-D-glyceroyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13dpg_f "3-Phospho-D-glyceroyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13dpg_h "3-Phospho-D-glyceroyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13dpg_m "3-Phospho-D-glyceroyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13oocdcy1829Z11Ea_c "(9Z,11E)-13-Oxooctadeca-9,11-dienoic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13Shocdcy1829Z11Ea_c "(9Z,11E)-(13S)-13-Hydroxyoctadeca-9,11-dienoic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M
">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mdr1p_c "5-Methylthio-5-deoxy-D-ribose 1-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mdru1p_c "5-Methylthio-5-deoxy-D-ribulose 1-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mta_c "5-Methylthioadenosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mta_h "5-Methylthioadenosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mta_m "5-Methylthioadenosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5mtr_c "5-Methylthio-D-ribose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5prdmbz_c "N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6mpur_c "6-Mercaptopurine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6mpur_e "6-Mercaptopurine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgc_c "6-Phospho-D-gluconate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgc_h "6-Phospho-D-gluconate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgl_c "6-phospho-D-glucono-1,5-lactone">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgl_h "6-phospho-D-glucono-1,5-lactone">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6tgsnmp_c "6-Thioguanosine monophosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6tins5mp_c "6-Thioinosine-5'-monophosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6txan5mp_c "6-Thioxanthine 5'-monophosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_7dhchsterol_c "Cholesta-5,7-dien-3beta-ol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aacoa_c "Acetoacetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aacoa_m "Acetoacetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aacoa_x "Acetoacetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_e "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_h "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_m "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_s "Acetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acac_c "Acetoacetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acac_m "Acetoacetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acac_x "Acetoacetate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acald_c "Acetaldehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acald_h "Acetaldehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acald_m "Acetaldehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acald_x "Acetaldehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_accoa_c "Acetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_accoa_h "Acetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_accoa_m "Acetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_accoa_s "Acetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_accoa_x "Acetyl-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acg5p_c "N-Acetyl-L-glutamyl 5-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acg5sa_c "N-Acetyl-L-glutamate 5-semialdehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acg5sa_m "N-Acetyl-L-glutamate 5-semialdehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acgam1p_c "N-Acetyl-D-glucosamine 1-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acgam6p_c "N-Acetyl-D-glucosamine 6-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acglu_c "N-Acetyl-L-glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_achms_c "O-Acetyl-L-homoserine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_achms_h "O-Acetyl-L-homoserine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acorn_c "N2-Acetyl-L-ornithine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acorn_m "N2-Acetyl-L-ornithine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_c "acyl carrier protein">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ACP_h "acyl carrier protein">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acser_c "O-Acetyl-L-serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acser_h "O-Acetyl-L-serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_acser_m "O-Acetyl-L-serine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ad_c "acetamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ad_e "acetamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ade_c "Adenine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ade_e "Adenine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adn_c "Adenosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adn_m "Adenosine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_c "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_f "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_h "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_m "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_n "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adprib_c "ADPribose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aflbala_c "alpha-Fluoro-beta-alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aflburppa_c "alpha-Fluoro-beta-ureidopropionic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahcys_c "S-Adenosyl-L-homocysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahcys_g "S-Adenosyl-L-homocysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahcys_h "S-Adenosyl-L-homocysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahcys_m "S-Adenosyl-L-homocysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahcys_n "S-Adenosyl-L-homocysteine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ahdt_c "2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridinetriphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aicar_c "5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aicar_h "5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_air_c "5-amino-1-(5-phospho-D-ribosyl)imidazole">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_air_h "5-amino-1-(5-phospho-D-ribosyl)imidazole">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_c "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_h "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_m "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_B_c "beta-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_B_h "beta-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_B_m "beta-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_c "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_m "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ala_DASH_L_x "L-Alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_allphn_c "Allophanate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_allphn_m "Allophanate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltn_c "Allantoin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltn_e "Allantoin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltn_m "Allantoin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltt_c "Allantoate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltt_e "Allantoate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_alltt_m "Allantoate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amet_c "S-Adenosyl-L-methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amet_g "S-Adenosyl-L-methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amet_h "S-Adenosyl-L-methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amet_m "S-Adenosyl-L-methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amet_n "S-Adenosyl-L-methionine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ametam_c "S-Adenosylmethioninamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ametam_h "S-Adenosylmethioninamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ametam_m "S-Adenosylmethioninamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_c "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_h "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_m "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_n "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ans_c "Anserine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_apoACP_c "Apo-[acyl-carrier-protein]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_apoACP_h "Apo-[acyl-carrier-protein]">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aps_c "Adenosine 5'-phosphosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aps_h "Adenosine 5'-phosphosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aps_m "Adenosine 5'-phosphosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_aps_n "Adenosine 5'-phosphosulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arab_DASH_L_c "L-Arabinose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_c "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_e "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arg_DASH_L_m "L-Arginine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_argsuc_c "N(omega)-(L-Arginino)succinate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_argtrna_c "L-Arginyl-tRNA(Arg)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_arso4_c "Aryl sulfate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asnglcnacglcnacman_DASH_LPAREN_DASH_man_DASH_LPAREN_DASH_manman_DASH_RPAREN_DASH_manman_DASH_RPAREN_DASH_manmanman_c "Asn(-b1)GlcNAc(4-b1)GlcNAc(4-b1)Man[(6-a1)Man[(6-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man(2-a1)Man">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asnglcnacglcnacman_DASH_LPAREN_DASH_man_DASH_LPAREN_DASH_manman_DASH_RPAREN_DASH_manman_DASH_RPAREN_DASH_manmanmanglc_c "Asn(-b1)GlcNAc(4-b1)GlcNAc(4-b1)Man[(6-a1)Man[(6-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man(2-a1)Man(3-a1)Glc">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asnglcnacglcnacman_DASH_LPAREN_DASH_man_DASH_LPAREN_DASH_manman_DASH_RPAREN_DASH_manman_DASH_RPAREN_DASH_manmanmanglcglc_c "Asn(-b1)GlcNAc(4-b1)GlcNAc(4-b1)Man[(6-a1)Man[(6-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man(2-a1)Man(3-a1)Glc(3-a1)Glc">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asnglcnacglcnacman_DASH_LPAREN_DASH_man_DASH_LPAREN_DASH_manman_DASH_RPAREN_DASH_manman_DASH_RPAREN_DASH_manmanmanglcglcglc_c "Asn(-b1)GlcNAc(4-b1)GlcNAc(4-b1)Man[(6-a1)Man[(6-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man](3-a1)Man(2-a1)Man(2-a1)Man(3-a1)Glc(3-a1)Glc(2-a1)Glc">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_asnglcnacglcnacman_DASH_LPAREN_DASH_man_DASH_LPAREN_DASH_manman_DASH_RPAREN_DASH_man_DASH_RPAREN_DASH_man_DASH_LPAREN_DASH_man_DASH_RPAREN_DASH_manman_c "Asn(-b1)GlcNAc(4-b1)GlcNAc(4-b1)Man[(6-a1)Man[(6-a1)Man(2-a1)Man](3-a1)Man](3-a1)Man[(6-a1)Man](2-a1)Man(2-a1)Man">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_
0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ca_c "coniferonic acid (18:4(5Z,9Z,12Z,15Z))">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cacoa_c "coniferonyl-coa">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cala_c "N-Carbamoyl-beta-alanine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_camp_c "cAMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_camp_n "cAMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cat_c "Calcitriol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cbasp_c "N-Carbamoyl-L-aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cbasp_m "N-Carbamoyl-L-aspartate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cbp_c "Carbamoyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cbp_h "Carbamoyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cbp_m "Carbamoyl phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp_c "CDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp_m "CDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp12dgr18111Z160_c "CDP-1-(9Z)-octadecenoyl,2-hexadecanoyl-sn-glycerol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp12dgr18111Z160_h "CDP-1-(9Z)-octadecenoyl,2-hexadecanoyl-sn-glycerol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp12dgr1819Z160_c "CDP-1-(11Z)-octadecenoyl,2-hexadecanoyl-sn-glycerol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdp12dgr1819Z160_h "CDP-1-(11Z)-octadecenoyl,2-hexadecanoyl-sn-glycerol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cdpea_c "CDPethanolamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_chlstol_c "5alpha-Cholesta-7,24-dien-3beta-ol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_chor_c "chorismate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_chor_h "chorismate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_chsterol_c "Cholesterol">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cit_c "Citrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cit_m "Citrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cit_x "Citrate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cital_c "Citalopram">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cital_e "Citalopram">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citalald_c "Citalopram aldehyde">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citalo_c "Citalopram N-oxide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citalppa_c "Citalopram propionic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citr_DASH_L_c "L-Citrulline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citr_DASH_L_h "L-Citrulline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_citr_DASH_L_m "L-Citrulline">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cmp_c "CMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cmp_h "CMP">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CS "citrate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CSm "citrate synthase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_CSx "citrate synthase, glyoxysomal">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ICDHm "isocitrate dehydrogenase (NAD)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MDH_LPAREN_nadp_RPAREN_fi "malate dehydrogenase (NADP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SUCL_LPAREN_gdp_RPAREN_m "succinyl-CoA ligase (GDP-forming)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PCr "Pyruvate carboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MDHf "malate dehydrogenase, flagellar">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MDHh "malate dehydrogenase, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MDHm "malate dehydrogenase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MDHx "malate dehydrogenase (NAD)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACONTm "Aconitate hydratase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FUMm "fumarate hydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ICDH "isocitrate dehydrogenase (NADP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ICDHhr "Isocitrate dehydrogenase (NADP+), reversible">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SUCLm "succinyl-CoA ligase (ADP-forming)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SUCDH_LPAREN_q8_RPAREN_m "succinate dehydrogenase (ubiquinone)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SUCDHm "succinate dehydrogenase Complex II">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PPCKm "phosphoenolpyruvate carboxykinase, mitochondria">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PPCK "phosphoenolpyruvate carboxykinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DEDOLDPS "dehydrodolichol diphosphate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DEDOLDPSAT "dehydrodolichol diphosphate saturase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TTCGGDPS "trans,trans,cis-geranylgeranyl diphosphate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TRP23OR "L-tryptophan:oxygen 2,3-oxidoreductase (decyclizing)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_34HPPYRI "3-(4-Hydroxyphenyl)pyruvate keto-enol-isomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAA "fumarylacetoacetase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HGDO "homogentisate 1,2-dioxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HPPD "p-hydroxyphenylpyruvate dioxygenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MAAI "maleylacetoacetate isomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MAAIn "maleylacetoacetate isomerase, nucleus">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TAT "L-tyrosine:2-oxoglutarate aminotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ALPH "allophanate hydrolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ALPHm "allophanate hydrolase, mitochondria">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_URCB "urea carboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACAS_LPAREN_2ahbut_RPAREN_ "acetolactate synthase, 2-Aceto-2-hydroxybutanoate forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAD "dihydroxy-acid dehydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAD_LPAREN_3mob_RPAREN_ "dihydroxy-acid dehydratase, 3-Methyl-2-oxobutanoate ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAD_LPAREN_3mob_RPAREN_h "dihydroxy-acid dehydratase, 3-Methyl-2-oxobutanoate, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHADh "dihydroxy-acid dehydratase, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ILETL "isoleucine---tRNA ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IMDH "3-isopropylmalate dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IMDHT "3-isopropylmalate dehydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IMDHT_LPAREN_3c2hmp_RPAREN_ "3-isopropylmalate dehydratase, 3-Carboxy-2-hydroxy-4-methylpentanoate forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IPMS "2-isopropylmalate synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KARI "ketol-acid reductoisomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KARI_LPAREN_23dhmb_RPAREN_ "ketol-acid reductoisomerase, (R)-2,3-Dihydroxy-3-methylbutanoate forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KARI_LPAREN_23dhmp_RPAREN_ "ketol-acid reductoisomerase, (R)-2,3-Dihydroxy-3-methylpentanoate forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KARI_LPAREN_3hmoa_RPAREN_ "ketol-acid reductoisomerase,  3-Hydroxy-3-methyl-2-oxobutanoic acid forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LEUTL "leucine---tRNA ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOPC "4-Methyl-2-oxopentanoate conversion">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TAL "threonine ammonia-lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_VALTL "valine---tRNA ligase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_VALTLh "valine---tRNA ligase, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ACCAT "Acetyl-CoA C-acyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ALDH "aldehyde dehydrogenase (NAD+)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRT_LPAREN_2mbcoa_RPAREN_ "dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, 2-Methylbutanoyl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRT_LPAREN_ibcoa_RPAREN_ "dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, Isobutyryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHRT_LPAREN_ivcoa_RPAREN_ "dihydrolipoyllysine-residue (2-methylpropanoyl)transferase, Isovaleryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ECH_LPAREN_3hibutcoa_RPAREN_ "enoyl-coa hydratase, 3-Hydroxyisobutyryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ECH_LPAREN_3hivcoa_RPAREN_ "enoyl-coa hydratase, 3-Hydroxyisovaleryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ECH_LPAREN_3hmbcoa_RPAREN_ "enoyl-coa hydratase, 3-Hydroxy-2-methylbutyryl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HIBH "3-hydroxyisobutyryl-coa hydrolase, mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMGL "hydroxymethylglutaryl-coa lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMNO "3-Hydroxy-2-methylpropanoate:NAD+ oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_HMNOS "(2S,3S)-3-hydroxy-2-methylbutanoyl-CoA:NAD+ oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_IVCDH "isovaleryl-coa dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MCDH "2-methylacyl-coa dehydrogenase, 2-Methylprop-2-enoyl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MCDH_LPAREN_2mb2coa_RPAREN_ "2-methylacyl-coa dehydrogenase, trans-2-Methylbut-2-enoyl-CoA forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MCTC "methylcrotonoyl-coa carboxylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MGC "methylglutaconyl-coa hydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MHGS "hydroxymethylglutaryl-coa synthase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MMSDH "methylmalonate-semialdehyde dehydrogenase (acylating)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD "3-methyl-2-oxobutanoate dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_2mbdhl_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 2-Methyl-1-hydroxybutyl-ThPP transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_2mhop_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 2-Methyl-1-hydroxypropyl-ThPP transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_3mhtpp_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-1-hydroxybutyl-ThPP transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_3mop_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 3-Methyl-2-oxopentanoate transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_MOD_LPAREN_4mop_RPAREN_ "3-methyl-2-oxobutanoate dehydrogenase, 4-Methyl-2-oxopentanoate transforming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_OIVD3m "2-oxoisovalerate dehydrogenase (acylating; 3-methyl-2-oxopentanoate), mitochondrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTA "branched-chain-amino-acid transaminase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTA_LPAREN_glu_RPAREN_ "branched-chain-amino-acid transaminase, glutamate forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTA_LPAREN_glu_RPAREN_h "branched-chain-amino-acid transaminase, glutamate forming, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTA_LPAREN_val_RPAREN_ "branched-chain-amino-acid transaminase, valine forming">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTA_LPAREN_val_RPAREN_h "branched-chain-amino-acid transaminase, valine forming, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BCTAh "branched-chain-amino-acid transaminase, chloroplast">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PDX5POi "Pyridoxine 5-phosphate:oxygen oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PDXPP "Pyridoxine-5'-phosphate phosphohydrolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYAM5PO "Pyridoxamine-5'-phosphate:oxygen oxidoreductase (deaminating)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYAMPP "Pyridoxamine-5'-phosphate phosphohydrolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDAMK "ATP:pyridoxal 5'-phosphotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXDH "Pyridoxal:oxygen 4-oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXK "ATP:pyridoxal 5'-phosphotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXNK "ATP:pyridoxine 5'-phosphotransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXNO "Pyridoxine:oxygen oxidoreductase (deaminating)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXO "Pyridoxamine:oxygen oxidoreductase (deaminating)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXOR "Pyridoxine:NADP+ 4-oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXPP "Pyridoxal-5'-phosphate phosphohydrolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PYDXS "Pyridoxal 5-phosphate synthase">

# %%
original_model
# Out:
# <Model iRC1080 at 0x19e3e0b54f0>

# %% [markdown]
# ##### 1.b) Calculate formula and/or charge ?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> /!\ Note that if you select formula = False, the molecular weight cannot be calculated from the metabolite formula preventing unit conversion.
#
# - Level 1 data must be given in mmol.gDW-1.
#
# - Levels 2 and 3 data must be given in mol per ...
#
# </div>

# %%
# All metabolites does not have a formula, for example:
original_model.metabolites.mgdg1839Z12Z15Z1634Z7Z10Z_h
# Out:
# <Metabolite mgdg1839Z12Z15Z1634Z7Z10Z_h at 0x19e52790440>

# %%
calculate_formula = False
calculate_charge = False

# %% [markdown]
# ##### 1.c) Choose a compartment to add biomass reactions

# %% [markdown]
# •	Reactions and pseudo metabolites will be added in compartment given by the user.
#
# •	Compartment must be chosen among model's compartment (key of cobra_model.compartments dictionary).
#
# •	Biomass reactions are commonly added in cytoplasm ("c").

# %%
# Compartments in model:
original_model.compartments
# Out:
# {'c': 'Cytosol',
#  'h': 'Chloroplast',
#  'm': 'Mitochondria',
#  'x': 'Glyoxysome',
#  'f': 'Flagellum',
#  'e': 'Extra-organism',
#  'n': 'Nucleus',
#  'g': 'Golgi Apparatus',
#  's': 'Eyespot',
#  'u': 'Thylakoid Lumen'}

# %%
BOF_compartment = "c"

# %% [markdown]
# ### 2 – Biomass composition data

# %% [markdown]
# ##### 2.a) Define data file

# %% [markdown]
# Data must be given in an Excel file with a specific format.
# See data_template.xlsx

# %%
path_to_data = "Biomass_composition_iRC1080_Chang2011_onelevelBOF.xlsx"

# %% [markdown]
# ### 3 – Structure of biomass objective function

# %% [markdown]
# ##### 3.a) Biomass reaction structure

# %% [markdown]
# ###### Dictionary defining BOF structure:
#
# Must be defined in accordance with Excel data file (sheet names).
#
# - Mandatory :
#      - one and only one key with value = "level_1"
# - Optional:
#     - if desired structure contains two or more levels:
#         - one or several key(s) with value = "level_2"
#      - if desired structure contains three levels:
#          - one and only one key with value = "level_2_lipid"
#          - one or several key(s) with value = "level_2"

# %%
dict_structure_BOF = {'BIOMASS': 'level_1'}

# %% [markdown]
# ##### 3.b) Choose a suffix

# %% [markdown]
# - Expected suffix: string containing only alphanumeric characters or _
#
# - Test performed in BioModTool: re.match("^[a-zA-Z0-9_]*$",suffix)
#
#
# All added reactions and pseudo-metabolites will contain the following tag: biomass_suffix_c.

# %%
suffix = "BioModTool_onelevel"

# %% [markdown]
# ### 4 – Create and add the new biomass objective function

# %%
updated_model = BioModTool.main_add_biomass_objective_function.add_biomass_objective_function(
    cobra_model = original_model,
    path_to_data = path_to_data,
    suffix = suffix,
    dict_structure = dict_structure_BOF,
    user_compartment = BOF_compartment,
    calculate_charge = calculate_charge,
    calculate_formula = calculate_formula,
    saving_final_data = True)
# Out:
# Metabolite BIOMASS_BioModTool_onelevel_c (formula: None, charge: None) added to model.
# Reaction BIOMASS_BioModTool_onelevel_c added to model.
# 0.03706 ac_c + 0.0005 acaro_h + 0.27375 ala_DASH_L_c + 0.0001 anxan_u + 0.52414 arab_DASH_L_c + 0.1502 arg_DASH_L_c + 0.06783 asn_DASH_L_c + 0.06783 asp_DASH_L_c + 0.00118 asqdca18111Z160_c + 0.00118 asqdca1819Z160_c + 0.00119 asqdca1829Z12Z160_c + 0.00119 asqdca1839Z12Z15Z160_c + 0.00118 asqdpa18111Z160_c + 0.00118 asqdpa1819Z160_c + 0.00118 asqdpa1829Z12Z160_c + 0.00119 asqdpa1839Z12Z15Z160_c + 29.948620000000002 atp_c + 0.02526 but_c + 0.00141 caro_u + 0.01008 chla_u + 0.01655 chlb_u + 0.10421 ctp_c + 0.00242 cys_DASH_L_c + 0.00218 datp_c + 0.00388 dctp_c + 0.00173 dgdg1819Z160_h + 0.0003 dgdg1819Z1617Z_h + 0.0003 dgdg1819Z1619Z_h + 0.0004 dgdg1819Z1627Z10Z_h + 0.0002 dgdg1819Z1634Z7Z10Z_h + 0.0002 dgdg1819Z1637Z10Z13Z_h + 0.00333 dgdg1829Z12Z160_h + 0.0003 dgdg1829Z12Z1617Z_h + 0.0003 dgdg1829Z12Z1619Z_h + 0.00054 dgdg1829Z12Z1627Z10Z_h + 0.00027 dgdg1829Z12Z1634Z7Z10Z_h + 0.00027 dgdg1829Z12Z1637Z10Z13Z_h + 0.0024 dgdg1839Z12Z15Z160_h + 0.00054 dgdg1839Z12Z15Z1627Z10Z_h + 0.00074 dgdg1839Z12Z15Z1634Z7Z10Z_h + 0.00074 dgdg1839Z12Z15Z1637Z10Z13Z_h + 0.00027 dgdg1839Z12Z15Z1644Z7Z10Z13Z_h + 0.00388 dgtp_c + 8e-05 dgts16018111Z_c + 8e-05 dgts1601819Z_c + 0.00111 dgts1601829Z12Z_c + 0.0039 dgts1601835Z9Z12Z_c + 0.00209 dgts1601845Z9Z12Z15Z_c + 7e-05 dgts18111Z18111Z_c + 7e-05 dgts18111Z1819Z_c + 0.0002 dgts18111Z1829Z12Z_c + 0.0004 dgts18111Z1835Z9Z12Z_c + 0.00027 dgts18111Z1845Z9Z12Z15Z_c + 7e-05 dgts1819Z18111Z_c + 7e-05 dg
1601819Z180_c + 0.00129 tag1601819Z18111Z_c + 0.00129 tag1601819Z1819Z_c + 0.00129 tag1601819Z1835Z9Z12Z_c + 0.0013 tag1601819Z1845Z9Z12Z15Z_c + 0.00129 tag1801819Z160_c + 0.00124 tag1801819Z180_c + 0.00125 tag1801819Z18111Z_c + 0.00125 tag1801819Z1819Z_c + 0.00125 tag1801819Z1835Z9Z12Z_c + 0.00126 tag1801819Z1845Z9Z12Z15Z_c + 0.00129 tag18111Z18111Z160_c + 0.00125 tag18111Z18111Z180_c + 0.00125 tag18111Z18111Z18111Z_c + 0.00125 tag18111Z18111Z1819Z_c + 0.00126 tag18111Z18111Z1835Z9Z12Z_c + 0.00126  ...
# ---------------------------------------------------------------------------------------------------------------------

# %%
updated_model.reactions.BIOMASS_BioModTool_onelevel_c
# Out:
# <Reaction BIOMASS_BioModTool_onelevel_c at 0x19e599056a0>

# %% [markdown]
# ### 5 – Save updated model

# %% [markdown]
# Save model in both json and sbml formats.

# %%
BioModTool.save.save_model(updated_model,"iRC1080_updated")

# %% [markdown]
# ### 6 – Test mass and charge balance of the new biomass reaction

# %%
BioModTool.test.test_BOF_by_suffix(updated_model,suffix)  # no formula
# Out:
#                                       C         H      N         O        S  \
# BIOMASS_BioModTool_onelevel_c -22.28443  18.06969 -3.142  12.56468 -0.01527
#
#                                      P
# BIOMASS_BioModTool_onelevel_c -1.02327

# %% [markdown]
# ### 7 – Test simulation with new biomass reaction

# %% [markdown]
# ##### 7.a) Objective = BIOMASS_BioModTool_onelevel_c  (new BOF)

# %%
updated_model.metabolites.BIOMASS_BioModTool_onelevel_c.formula

# %%
new_biomass_id = "BIOMASS_BioModTool_onelevel_c"

# %%
updated_model.objective = new_biomass_id
pfba_cobra(updated_model)
# Out:
# <Solution 7672.107 at 0x19e59f6a030>

# %%
updated_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_BioModTool_onelevel_c = 6.15664979744843</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>2</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_LPAREN_e_RPAREN_</td>
#       <td>0.164</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_LPAREN_e_RPAREN_</td>
#       <td>8.487</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis_LPAREN_e_RPAREN_</td>
#       <td>1401</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_LPAREN_e_RPAREN_</td>
#       <td>6.343</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_LPAREN_e_RPAREN_</td>
#       <td>0.1184</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>starch300_h</td>
#       <td>EX_starch_LPAREN_h_RPAREN_</td>
#       <td>0.2098</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>na1_h</td>
#       <td>DM_na1_LPAREN_h_RPAREN_</td>
#       <td>-10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2D_u</td>
#       <td>DM_o2D_LPAREN_u_RPAREN_</td>
#       <td>-8.28</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon298_c</td>
#       <td>DM_photon298_LPAREN_c_RPAREN_</td>
#       <td>-4.03</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon438_u</td>
#       <td>DM_photon438_LPAREN_u_RPAREN_</td>
#       <td>-235.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon450_h</td>
#       <td>DM_photon450_LPAREN_h_RPAREN_</td>
#       <td>-144.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon490_s</td>
#       <td>DM_photon490_LPAREN_s_RPAREN_</td>
#       <td>-232.4</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon646_h</td>
#       <td>DM_photon646_LPAREN_h_RPAREN_</td>
#       <td>-325.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon673_u</td>
#       <td>DM_photon673_LPAREN_u_RPAREN_</td>
#       <td>-123.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>BIOMASS_BioModTool_onelevel_c</td>
#       <td>EX_BIOMASS_BioModTool_onelevel_</td>
#       <td>-6.157</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_LPAREN_e_RPAREN_</td>
#       <td>-74.35</td>
#       <td>1</td>
#       <td>45.96%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_LPAREN_e_RPAREN_</td>
#       <td>-40.71</td>
#       <td>2</td>
#       <td>50.33%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_LPAREN_e_RPAREN_</td>
#       <td>-5.988</td>
#       <td>1</td>
#       <td>3.70%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_LPAREN_e_RPAREN_</td>
#       <td>-202.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 7.b) Objective = initial biomass reaction

# %%
original_model.reactions.Biomass_Chlamy_auto
# Out:
# <Reaction Biomass_Chlamy_auto at 0x19e5263bc20>

# %%
original_model.objective = "Biomass_Chlamy_auto"
pfba_cobra(original_model)
# Out:
# <Solution 7298.029 at 0x19e59c51910>

# %%
original_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Chlamy_auto = 6.156851475934288</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>2</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_LPAREN_e_RPAREN_</td>
#       <td>0.164</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_LPAREN_e_RPAREN_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_LPAREN_e_RPAREN_</td>
#       <td>8.488</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photonVis_e</td>
#       <td>EX_photonVis_LPAREN_e_RPAREN_</td>
#       <td>1401</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_LPAREN_e_RPAREN_</td>
#       <td>6.342</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_LPAREN_e_RPAREN_</td>
#       <td>0.1185</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>starch300_h</td>
#       <td>EX_starch_LPAREN_h_RPAREN_</td>
#       <td>0.2098</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>na1_h</td>
#       <td>DM_na1_LPAREN_h_RPAREN_</td>
#       <td>-10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2D_u</td>
#       <td>DM_o2D_LPAREN_u_RPAREN_</td>
#       <td>-8.28</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon298_c</td>
#       <td>DM_photon298_LPAREN_c_RPAREN_</td>
#       <td>-4.03</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon438_u</td>
#       <td>DM_photon438_LPAREN_u_RPAREN_</td>
#       <td>-235.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon450_h</td>
#       <td>DM_photon450_LPAREN_h_RPAREN_</td>
#       <td>-144.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon490_s</td>
#       <td>DM_photon490_LPAREN_s_RPAREN_</td>
#       <td>-232.4</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon646_h</td>
#       <td>DM_photon646_LPAREN_h_RPAREN_</td>
#       <td>-325.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon673_u</td>
#       <td>DM_photon673_LPAREN_u_RPAREN_</td>
#       <td>-123.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_LPAREN_e_RPAREN_</td>
#       <td>-74.36</td>
#       <td>1</td>
#       <td>45.96%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_LPAREN_e_RPAREN_</td>
#       <td>-40.71</td>
#       <td>2</td>
#       <td>50.33%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_LPAREN_e_RPAREN_</td>
#       <td>-5.987</td>
#       <td>1</td>
#       <td>3.70%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_LPAREN_e_RPAREN_</td>
#       <td>-18.48</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
