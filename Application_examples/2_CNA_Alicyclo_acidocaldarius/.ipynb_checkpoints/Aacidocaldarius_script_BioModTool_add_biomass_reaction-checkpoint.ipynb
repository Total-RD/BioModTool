# %% [markdown]
# # BioModTool validation: CNA_Alicyclo GEM

# %% [markdown]
# - Cobra model: S2_A_acidocaldarius_SBML
#
# - Biomass composition data from Beck et al., 2018

# %%
from cobra.flux_analysis.parsimonious import pfba as pfba_cobra

import BioModTool.load
import BioModTool.main_add_biomass_objective_function
import BioModTool.save

# %% [markdown]
# ### 1 - Load Genome Scale Metabolic Model

# %% [markdown]
# ##### 1.a) Model directory

# %% [markdown]
# GEM model must be given as a json or sbml/xml file.

# %%
path_to_model = "S2_A_acidocaldarius_SBML.xml"

# %%
original_model = BioModTool.load.load_cobra_model(path_to_model)
# Out:
# Model does not contain SBML fbc package information.
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# '1_3_bisphospho_D_glycerate' is not a valid SBML 'SId'.
# '10_formyl_tetrahydrofolate' is not a valid SBML 'SId'.
# '1_2_carboxyphenylamino_1_deoxy_D_ribulose_5_P' is not a valid SBML 'SId'.
# SBML package 'render' not supported by cobrapy, information is not parsed
# '1_3_bisphospho_D_glycerate' is not a valid SBML 'SId'.
# '10_formyl_tetrahydrofolate' is not a valid SBML 'SId'.
# '1_2_carboxyphenylamino_1_deoxy_D_ribulose_5_P' is not a valid SBML 'SId'.
# '2_3_dihydroxy_3_methylvalerate' is not a valid SBML 'SId'.
# '2_3_dihydroxy_3_methylvalerate' is not a valid SBML 'SId'.
# '2_3_dihydroxy_isovalerate' is not a valid SBML 'SId'.
# '2_3_dihydroxy_isovalerate' is not a valid SBML 'SId'.
# '2_aceto_2_hydroxy_butanoate' is not a valid SBML 'SId'.
# '2_aceto_2_hydroxy_butanoate' is not a valid SBML 'SId'.
# '2_acetolactate' is not a valid SBML 'SId'.
# '2_isopropyl_3_oxosuccinate' is not a valid SBML 'SId'.
# '2_isopropylmalate' is not a valid SBML 'SId'.
# '2_isopropylmaleate' is not a valid SBML 'SId'.
# '2_acetolactate' is not a valid SBML 'SId'.
# '2_isopropyl_3_oxosuccinate' is not a valid SBML 'SId'.
# '2_isopropylmalate' is not a valid SBML 'SId'.
# '2_isopropylmaleate' is not a valid SBML 'SId'.
# '2_keto_3_methyl_valerate' is not a valid SBML 'SId'.
# '2_keto_3_methyl_valerate' is not a valid SBML 'SId'.
# '2_oxobutanoate' is not a valid SBML 'SId'.
# '2_oxobutanoate' is not a valid SBML 'SId'.
# '2_oxoglutarate' is not a valid SBML 'SId'.
# '2_oxoglutarate' is not a valid SBML 'SId'.
# '2_oxoisovalerate' is not a valid SBML 'SId'.
# '2_oxoisovalerate' is not a valid SBML 'SId'.
# '2_phospho_D_glycerate' is not a valid SBML 'SId'.
# '2_phospho_D_glycerate' is not a valid SBML 'SId'.
# '3_dehydroquinate' is not a valid SBML 'SId'.
# '3_dehydroshikimate' is not a valid SBML 'SId'.
# '3_deoxy_D_arabino_hept_2_ulosonate_7_phosphate' is not a valid SBML 'SId'.
# '3_isopropylmalate' is not a valid SBML 'SId'.
# '3_dehydroquinate' is not a valid SBML 'SId'.
# '3_dehydroshikimate' is not a valid SBML 'SId'.
# '3_deoxy_D_arabino_hept_2_ulosonate_7_phosphate' is not a valid SBML 'SId'.
# '3_isopropylmalate' is not a valid SBML 'SId'.
# '3_phospho_D_glycerate' is not a valid SBML 'SId'.
# '3_phospho_D_glycerate' is not a valid SBML 'SId'.
# '3_phospho_hydroxypyruvate' is not a valid SBML 'SId'.
# '3_phospho_hydroxypyruvate' is not a valid SBML 'SId'.
# '3_phospho_L_serine' is not a valid SBML 'SId'.
# '3_phospho_L_serine' is not a valid SBML 'SId'.
# '4_hydroxyphenylpyruvate' is not a valid SBML 'SId'.
# '4_hydroxyphenylpyruvate' is not a valid SBML 'SId'.
# '4_methyl_2_oxopentanoate' is not a valid SBML 'SId'.
# '5_10_methenyltetrahydrofolate' is not a valid SBML 'SId'.
# '5_10_methylenetetrahydrofolate' is not a valid SBML 'SId'.
# '5_enolpyruvyl_shikimate_3_phosphate' is not a valid SBML 'SId'.
# '4_methyl_2_oxopentanoate' is not a valid SBML 'SId'.
# '5_10_methenyltetrahydrofolate' is not a valid SBML 'SId'.
# '5_10_methylenetetrahydrofolate' is not a valid SBML 'SId'.
# '5_enolpyruvyl_shikimate_3_phosphate' is not a valid SBML 'SId'.
# '5_methyl_tetrahydrofolate' is not a valid SBML 'SId'.
# '5_methyl_tetrahydrofolate' is not a valid SBML 'SId'.
# '5_phospho_a_D_ribose_1_diphosphate' is not a valid SBML 'SId'.
# '5_phospho_a_D_ribose_1_diphosphate' is not a valid SBML 'SId'.
# '5_phospho_b_D_ribosyl_amine' is not a valid SBML 'SId'.
# '5_phospho_b_D_ribosyl_amine' is not a valid SBML 'SId'.
# '5_phospho_ribosyl_glycineamide' is not a valid SBML 'SId'.
# '5_phospho_ribosyl_glycineamide' is not a valid SBML 'SId'.
# '5_phosphoribosyl_N_formalglycineamide' is not a valid SBML 'SId'.
# '5_phosphoribosyl_N_formalglycineamide' is not a valid SBML 'SId'.
# '5_phosphoribosyl_N_formylglycineamidine' is not a valid SBML 'SId'.
# '5_phosphoribosyl_N_formylglycineamidine' is not a valid SBML 'SId'.
# '5_P_ribosyl_anthranilate' is not a valid SBML 'SId'.
# '6_phospho_D_gluconate' is not a valid SBML 'SId'.
# '6_phospho_D_glucono_1_5_lactone' is not a valid SBML 'SId'.
# '7_8_dihydrofolate_monoglutamate' is not a valid SBML 'SId'.
# '5_P_ribosyl_anthranilate' is not a valid SBML 'SId'.
# '6_phospho_D_gluconate' is not a valid SBML 'SId'.
# '6_phospho_D_glucono_1_5_lactone' is not a valid SBML 'SId'.
# '7_8_dihydrofolate_monoglutamate' is not a valid SBML 'SId'.
# Adding exchange reaction EX_ammonium_ext with default bounds for boundary metabolite: ammonium_ext.
# Adding exchange reaction EX_ammonium_ext with default bounds for boundary metabolite: ammonium_ext.
# Adding exchange reaction EX_biomass_ext with default bounds for boundary metabolite: biomass_ext.
# Adding exchange reaction EX_biomass_ext with default bounds for boundary metabolite: biomass_ext.
# Adding exchange reaction EX_CO2_ext with default bounds for boundary metabolite: CO2_ext.
# Adding exchange reaction EX_CO2_ext with default bounds for boundary metabolite: CO2_ext.
# Adding exchange reaction EX_energy_ext with default bounds for boundary metabolite: energy_ext.
# Adding exchange reaction EX_energy_ext with default bounds for boundary metabolite: energy_ext.
# Adding exchange reaction EX_glucose_ext with default bounds for boundary metabolite: glucose_ext.
# Adding exchange reaction EX_H__ext with default bounds for boundary metabolite: H__ext.
# Adding exchange reaction EX_glucose_ext with default bounds for boundary metabolite: glucose_ext.
# Adding exchange reaction EX_H__ext with default bounds for boundary metabolite: H__ext.
# Adding exchange reaction EX_H2O_ext with default bounds for boundary metabolite: H2O_ext.
# Adding exchange reaction EX_H2O_ext with default bounds for boundary metabolite: H2O_ext.
# Adding exchange reaction EX_oxygen_ext with default bounds for boundary metabolite: oxygen_ext.
# Adding exchange reaction EX_oxygen_ext with default bounds for boundary metabolite: oxygen_ext.
# Adding exchange reaction EX_phosphate_ext with default bounds for boundary metabolite: phosphate_ext.
# Adding exchange reaction EX_phosphate_ext with default bounds for boundary metabolite: phosphate_ext.
# Adding exchange reaction EX_sulfate_ext with default bounds for boundary metabolite: sulfate_ext.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C1 "C1">'
# Adding exchange reaction EX_sulfate_ext with default bounds for boundary metabolite: sulfate_ext.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C1 "C1">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C1 "C1">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C2 "C2">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C2 "C2">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C3 "C3">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C1 "C1">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C2 "C2">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C2 "C2">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C3 "C3">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C3 "C3">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C3 "C3">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C4 "C4">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C4 "C4">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C4 "C4">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C5 "C5">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C4 "C4">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C5 "C5">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C5 "C5">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C6 "C6">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C6 "C6">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C7 "C7">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C5 "C5">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C6 "C6">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C6 "C6">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C7 "C7">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C7 "C7">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C7 "C7">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C8 "C8">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C8 "C8">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C8 "C8">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C8 "C8">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C9 "C9">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C9 "C9">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C10 "C10">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C10 "C10">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C11 "C11">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C11 "C11">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C9 "C9">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C9 "C9">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C10 "C10">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C10 "C10">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C11 "C11">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C11 "C11">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C12 "C12">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C12 "C12">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C12 "C12">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C12 "C12">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C13 "C13">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C13 "C13">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C13 "C13">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C13 "C13">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C14 "C14">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C14 "C14">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C14 "C14">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C14 "C14">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C15 "C15">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C15 "C15">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C15 "C15">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C15 "C15">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C16 "C16">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C16 "C16">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C16 "C16">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C16 "C16">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C17 "C17">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C17 "C17">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C17 "C17">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C17 "C17">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C18 "C18">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C18 "C18">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C18 "C18">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C18 "C18">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C19 "C19">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C19 "C19">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C19 "C19">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C19 "C19">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C20 "C20">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C20 "C20">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C20 "C20">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C20 "C20">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C21 "C21">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C21 "C21">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C21 "C21">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C21 "C21">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C22 "C22">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C22 "C22">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C22 "C22">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C22 "C22">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C23 "C23">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C23 "C23">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C23 "C23">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C23 "C23">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C24 "C24">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C24 "C24">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C24 "C24">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C24 "C24">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C25 "C25">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C25 "C25">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C25 "C25">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C25 "C25">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C26 "C26">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C26 "C26">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C26 "C26">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C26 "C26">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C27 "C27">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C27 "C27">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C27 "C27">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C27 "C27">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C28 "C28">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C28 "C28">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C28 "C28">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C28 "C28">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C29 "C29">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C29 "C29">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C29 "C29">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C29 "C29">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C30 "C30">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C30 "C30">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C30 "C30">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C30 "C30">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C31 "C31">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C31 "C31">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C31 "C31">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C31 "C31">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C32 "C32">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction C32 "C32">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C32 "C32">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction C32 "C32">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction
'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B2 "B2">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B3 "B3">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B3 "B3">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B3 "B3">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B3 "B3">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B4 "B4">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B4 "B4">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B4 "B4">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B4 "B4">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B5 "B5">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction B5 "B5">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B5 "B5">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction B5 "B5">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction E0 "E0">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction E0 "E0">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction E0 "E0">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction E0 "E0">'
# No objective coefficients in model. Unclear what should be optimized
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.

# %%
original_model
# Out:
# <Model CNA_Alicyclo at 0x22972c3f620>
# <Model CNA_Alicyclo at 0x22972c3f620>

# %% [markdown]
# ##### 1.b) Calculate formula and/or charge ?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> /!\ Note that if you select formula = False, the molecular weight cannot be calculated from the metabolite formula preventing unit conversion.
#
# - Level 1 data must be given in mmol.gDW-1.
#
# - Levels 2 and 3 data must be given in mol per ...
#
# </div>

# %%
calculate_formula = False
calculate_charge = False

# %% [markdown]
# ##### 1.c) Choose a compartment to add biomass reactions

# %% [markdown]
# •	Reactions and pseudo metabolites will be added in compartment given by the user.
#
# •	Compartment must be chosen among model's compartment (key of cobra_model.compartments dictionary).
#
# •	Biomass reactions are commonly added in cytoplasm ("c").

# %%
# Compartments in model:
original_model.compartments
# Out:
# {'Internal_Species': '', 'External_Species': ''}
# {'Internal_Species': '', 'External_Species': ''}

# %%
BOF_compartment = "Internal_Species"

# %% [markdown]
# ### 2 – Biomass composition data

# %% [markdown]
# ##### 2.a) Define data file

# %% [markdown]
# Data must be given in an Excel file with a specific format.
# See data_template.xlsx

# %%
path_to_data = "Biomass_composition_A_acidocaldarius_Beck2018.xlsx"

# %% [markdown]
# ### 3 – Structure of biomass objective function

# %% [markdown]
# ##### 3.a) Biomass reaction structure

# %% [markdown]
# ###### Dictionary defining BOF structure:
#
# Must be defined in accordance with Excel data file (sheet names).
#
# - Mandatory :
#      - one and only one key with value = "level_1"
# - Optional:
#     - if desired structure contains two or more levels:
#         - one or several key(s) with value = "level_2"
#      - if desired structure contains three levels:
#          - one and only one key with value = "level_2_lipid"
#          - one or several key(s) with value = "level_2"

# %%
dict_structure_BOF = { 'LIPIDS': 'level_2',
 'POLYSACCHARIDES': 'level_2',
 'DNA': 'level_2',
 'RNA': 'level_2',
 'PROTEINS': 'level_2',
 'BIOMASS': 'level_1'}

# %% [markdown]
# ##### 3.b) Choose a suffix

# %% [markdown]
# - Expected suffix: string containing only alphanumeric characters or _
#
# - Test performed in BioModTool: re.match("^[a-zA-Z0-9_]*$",suffix)
#
#
# All added reactions and pseudo-metabolites will contain the following tag: biomass_suffix_c.

# %%
suffix = "BioModTool_beck2018"

# %% [markdown]
# ### 4 – Create and add the new biomass objective function

# %%
updated_model = BioModTool.main_add_biomass_objective_function.add_biomass_objective_function(
    cobra_model = original_model,
    path_to_data = path_to_data,
    suffix = suffix,
    dict_structure = dict_structure_BOF,
    user_compartment = BOF_compartment,
    calculate_charge = calculate_charge,
    calculate_formula = calculate_formula,
    saving_final_data = True)
# Out:
# Metabolite LIPIDS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction LIPIDS_BioModTool_beck2018_Internal_Species added to model.
# 2.0 H_ + L_serine + 0.759708737864078 cyclohexanyltridecanoate + 1.24029126213592 cyclohexanylundecanoate + glycerol_3_phosphate --> 3.0 H2O + LIPIDS_BioModTool_beck2018_Internal_Species
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite POLYSACCHARIDES_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction POLYSACCHARIDES_BioModTool_beck2018_Internal_Species added to model.
# ATP + A_D_glucose_1_phosphate --> ADP + POLYSACCHARIDES_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite DNA_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction DNA_BioModTool_beck2018_Internal_Species added to model.
# 0.1905 dATP + 0.3095 dCTP + 0.3095 dGTP + 0.1905 dTTP --> DNA_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite RNA_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction RNA_BioModTool_beck2018_Internal_Species added to model.
# 0.15774 ATP + 0.35938 CTP + 0.24259 GTP + 0.2403 UTP --> RNA_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite PROTEINS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction PROTEINS_BioModTool_beck2018_Internal_Species added to model.
# ATP + 1.98 GTP + 1.9780000000000002 H2O + 0.11788 L_alanine + 0.05594 L_arginine + 0.02997 L_asparagine + 0.06494 L_aspartate + 0.00899 L_cysteine + 0.07338 L_glutamate + 0.03951 L_glutamine + 0.01698 L_histidine + 0.03896 L_isoleucine + 0.07293 L_leucine + 0.03796 L_lysine + 0.02597 L_methionine + 0.02797 L_phenylalanine + 0.04795 L_proline + 0.05594 L_serine + 0.06194 L_threonine + 0.01598 L_tryptophan + 0.02997 L_tyrosine + 0.08092 L_valine + 0.0959 glycine --> AMP + 1.98 GDP + 2.98 H_ + PROTEINS_BioModTool_beck2018_Internal_Species + diphosphate + 1.98 phosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite BIOMASS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction BIOMASS_BioModTool_beck2018_Internal_Species added to model.
# 0.03486 DNA_BioModTool_beck2018_Internal_Species + 0.06674 LIPIDS_BioModTool_beck2018_Internal_Species + 0.58648 POLYSACCHARIDES_BioModTool_beck2018_Internal_Species + 5.46497 PROTEINS_BioModTool_beck2018_Internal_Species + 0.79121 RNA_BioModTool_beck2018_Internal_Species --> BIOMASS_BioModTool_beck2018_Internal_Species + 55.8 energy_maintenance
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite LIPIDS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction LIPIDS_BioModTool_beck2018_Internal_Species added to model.
# 2.0 H_ + L_serine + 0.759708737864078 cyclohexanyltridecanoate + 1.24029126213592 cyclohexanylundecanoate + glycerol_3_phosphate --> 3.0 H2O + LIPIDS_BioModTool_beck2018_Internal_Species
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite POLYSACCHARIDES_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction POLYSACCHARIDES_BioModTool_beck2018_Internal_Species added to model.
# ATP + A_D_glucose_1_phosphate --> ADP + POLYSACCHARIDES_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite DNA_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction DNA_BioModTool_beck2018_Internal_Species added to model.
# 0.1905 dATP + 0.3095 dCTP + 0.3095 dGTP + 0.1905 dTTP --> DNA_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite RNA_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction RNA_BioModTool_beck2018_Internal_Species added to model.
# 0.15774 ATP + 0.35938 CTP + 0.24259 GTP + 0.2403 UTP --> RNA_BioModTool_beck2018_Internal_Species + diphosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite PROTEINS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction PROTEINS_BioModTool_beck2018_Internal_Species added to model.
# ATP + 1.98 GTP + 1.9780000000000002 H2O + 0.11788 L_alanine + 0.05594 L_arginine + 0.02997 L_asparagine + 0.06494 L_aspartate + 0.00899 L_cysteine + 0.07338 L_glutamate + 0.03951 L_glutamine + 0.01698 L_histidine + 0.03896 L_isoleucine + 0.07293 L_leucine + 0.03796 L_lysine + 0.02597 L_methionine + 0.02797 L_phenylalanine + 0.04795 L_proline + 0.05594 L_serine + 0.06194 L_threonine + 0.01598 L_tryptophan + 0.02997 L_tyrosine + 0.08092 L_valine + 0.0959 glycine --> AMP + 1.98 GDP + 2.98 H_ + PROTEINS_BioModTool_beck2018_Internal_Species + diphosphate + 1.98 phosphate
# ---------------------------------------------------------------------------------------------------------------------
# Metabolite BIOMASS_BioModTool_beck2018_Internal_Species (formula: None, charge: None) added to model.
# Reaction BIOMASS_BioModTool_beck2018_Internal_Species added to model.
# 0.03486 DNA_BioModTool_beck2018_Internal_Species + 0.06674 LIPIDS_BioModTool_beck2018_Internal_Species + 0.58648 POLYSACCHARIDES_BioModTool_beck2018_Internal_Species + 5.46497 PROTEINS_BioModTool_beck2018_Internal_Species + 0.79121 RNA_BioModTool_beck2018_Internal_Species --> BIOMASS_BioModTool_beck2018_Internal_Species + 55.8 energy_maintenance
# ---------------------------------------------------------------------------------------------------------------------

# %%
updated_model.reactions.BIOMASS_BioModTool_beck2018_Internal_Species
# Out:
# <Reaction BIOMASS_BioModTool_beck2018_Internal_Species at 0x229746928a0>
# <Reaction BIOMASS_BioModTool_beck2018_Internal_Species at 0x229746928a0>

# %% [markdown]
# ### 5 – Save updated model

# %% [markdown]
# Save model in both json and sbml formats.

# %%
BioModTool.save.save_model(updated_model,"S2_A_acidocaldarius_SBML_updated")

# %% [markdown]
# ### 6 – Test mass and charge balance of the new biomass reaction

# %%
BioModTool.test.test_BOF_by_suffix(updated_model,suffix) #OK but no formula nor charge
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7 – Test simulation with new biomass reaction

# %% [markdown]
# ##### 7.a) Objective = BIOMASS_BioModTool_beck2018_c (new BOF)

# %%
updated_model.remove_reactions(["B0","B1","B2","B3","B4","B5","EX_biomass_ext"])

# %%
updated_model.reactions.BIOMASS_BioModTool_beck2018_Internal_Species
# Out:
# <Reaction BIOMASS_BioModTool_beck2018_Internal_Species at 0x229746928a0>
# <Reaction BIOMASS_BioModTool_beck2018_Internal_Species at 0x229746928a0>

# %%
new_biomass_id = "BIOMASS_BioModTool_beck2018_Internal_Species"

# %%
updated_model.objective = new_biomass_id
pfba_cobra(updated_model)
# Out:
# <Solution 12973.377 at 0x229746a7530>
# <Solution 12973.377 at 0x229746a7530>

# %%
updated_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_BioModTool_beck2018_Internal_Species = 35.84229390681003</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ammonium_ext</td>
#       <td>EX_ammonium_ext</td>
#       <td>367.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glucose_ext</td>
#       <td>EX_glucose_ext</td>
#       <td>238.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phosphate_ext</td>
#       <td>EX_phosphate_ext</td>
#       <td>32</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sulfate_ext</td>
#       <td>EX_sulfate_ext</td>
#       <td>6.848</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>BIOMASS_BioModTool_beck2018_Internal_Species</td>
#       <td>EX_BIOMASS_BioModTool_beck2018_Internal_Specie</td>
#       <td>-35.84</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H2O_ext</td>
#       <td>EX_H2O_ext</td>
#       <td>-940.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H__ext</td>
#       <td>EX_H__ext</td>
#       <td>-333.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>energy_ext</td>
#       <td>EX_energy_ext</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>oxygen_ext</td>
#       <td>EX_oxygen_ext</td>
#       <td>-8.899</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Objective</h3><p>1.0 BIOMASS_BioModTool_beck2018_Internal_Species = 35.84229390681003</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ammonium_ext</td>
#       <td>EX_ammonium_ext</td>
#       <td>367.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glucose_ext</td>
#       <td>EX_glucose_ext</td>
#       <td>238.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phosphate_ext</td>
#       <td>EX_phosphate_ext</td>
#       <td>32</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sulfate_ext</td>
#       <td>EX_sulfate_ext</td>
#       <td>6.848</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>BIOMASS_BioModTool_beck2018_Internal_Species</td>
#       <td>EX_BIOMASS_BioModTool_beck2018_Internal_Specie</td>
#       <td>-35.84</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H2O_ext</td>
#       <td>EX_H2O_ext</td>
#       <td>-940.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H__ext</td>
#       <td>EX_H__ext</td>
#       <td>-333.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>energy_ext</td>
#       <td>EX_energy_ext</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>oxygen_ext</td>
#       <td>EX_oxygen_ext</td>
#       <td>-8.899</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 7.b) Objective = original BOF

# %%
original_model.reactions.B0
# Out:
# <Reaction B0 at 0x229730b80b0>
# <Reaction B0 at 0x229730b80b0>

# %%
original_model.objective = "B0"
pfba_cobra(original_model)
# Out:
# <Solution 15842.134 at 0x229745e2480>
# <Solution 15842.134 at 0x229745e2480>

# %%
original_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 B0 = 35.84229390681006</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ammonium_ext</td>
#       <td>EX_ammonium_ext</td>
#       <td>367.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>energy_ext</td>
#       <td>EX_energy_ext</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glucose_ext</td>
#       <td>EX_glucose_ext</td>
#       <td>238.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phosphate_ext</td>
#       <td>EX_phosphate_ext</td>
#       <td>31.99</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sulfate_ext</td>
#       <td>EX_sulfate_ext</td>
#       <td>6.849</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>H2O_ext</td>
#       <td>EX_H2O_ext</td>
#       <td>-940.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H__ext</td>
#       <td>EX_H__ext</td>
#       <td>-333.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>biomass_ext</td>
#       <td>EX_biomass_ext</td>
#       <td>-35.84</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>oxygen_ext</td>
#       <td>EX_oxygen_ext</td>
#       <td>-8.873</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Objective</h3><p>1.0 B0 = 35.84229390681006</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ammonium_ext</td>
#       <td>EX_ammonium_ext</td>
#       <td>367.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>energy_ext</td>
#       <td>EX_energy_ext</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glucose_ext</td>
#       <td>EX_glucose_ext</td>
#       <td>238.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phosphate_ext</td>
#       <td>EX_phosphate_ext</td>
#       <td>31.99</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sulfate_ext</td>
#       <td>EX_sulfate_ext</td>
#       <td>6.849</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>H2O_ext</td>
#       <td>EX_H2O_ext</td>
#       <td>-940.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H__ext</td>
#       <td>EX_H__ext</td>
#       <td>-333.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>biomass_ext</td>
#       <td>EX_biomass_ext</td>
#       <td>-35.84</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>oxygen_ext</td>
#       <td>EX_oxygen_ext</td>
#       <td>-8.873</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
